# %%
 import numpy as np # linear algebra
 import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv
 import matplotlib.pyplot as plt
 import missingno as msno
 import seaborn as sns
 sns.set()

# %%
raw_data = pd.read_csv('C:\\Users\\GPT BANTWAL\\Downloads\\medical_students_dataset (1).csv')
raw_data.head()
# Out:
#    Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1         2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2         3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3         NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4         5.0  23.0  Female         NaN  46.234173          O        NaN
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No     NaN
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No

# %%
raw_data.isnull().sum()
# Out:
# Student ID        20000
# Age               20000
# Gender            20000
# Height            20000
# Weight            20000
# Blood Type        20000
# BMI               20000
# Temperature       20000
# Heart Rate        20000
# Blood Pressure    20000
# Cholesterol       20000
# Diabetes          20000
# Smoking           20000
# dtype: int64

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB

# %%
msno.bar(raw_data)
# Out:
# <Axes: >

# %%
msno.matrix(raw_data)
# Out:
# <Axes: >

# %%
raw_data=pd.read_csv('C:\\Users\\GPT BANTWAL\\Downloads\\medical_students_dataset (1).csv')
raw_data
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927410  99.928405          O  42.175189
#
# ...

# %%
new_df=raw_data.fillna(method="ffill")
new_df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0  18.0    Male  152.069157  47.630941          B  27.645835
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              3.0  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female  182.112867  46.234173          O  19.096042
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995     99995.0  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194          B  16.831734
# 199997     99998.0  34.0  Female  163.917675  99.648914          B  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927410  99.928405          O  42.175189
#
# ...

# %%
new_df=raw_data.fillna(method="ffill",limit=1)
new_df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0  18.0    Male  152.069157  47.630941          B  27.645835
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              3.0  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female  182.112867  46.234173          O  19.096042
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995     99995.0  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194          B  16.831734
# 199997     99998.0  34.0  Female  163.917675  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927410  99.928405          O  42.175189
#
# ...

# %%
new_df=raw_data.fillna(method="bfill")
new_df
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0  32.0    Male  152.069157  47.630941          B  16.729017
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              5.0  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female  151.491294  46.234173          O  29.912403
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995     99997.0  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194          A  16.831734
# 199997     99998.0  34.0  Female  156.446944  99.648914          A  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927410  99.928405          O  42.175189
#
# ...

# %%
data=pd.read_csv('C:\\Users\\GPT BANTWAL\\Downloads\\medical_students_dataset (1).csv')
data
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927410  99.928405          O  42.175189
#
# ...

# %%
data.dropna()
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 7              8.0  28.0    Male  186.489402  52.389752         AB  15.063921
# 11            12.0  34.0  Female  182.416302  76.371050         AB  22.950992
# 19            20.0  31.0    Male  166.489929  49.955569          B  18.022207
# 22            23.0  29.0  Female  179.909041  90.679436         AB  28.015787
# ...            ...   ...     ...         ...        ...        ...        ...
# 199973     99974.0  25.0  Female  156.297842  90.690186          B  37.123963
# 199985     99986.0  23.0  Female  162.884951  82.485778          B  31.089745
# 199986     99987.0  34.0    Male  165.651315  93.099756          A  33.928040
# 199992     99993.0  34.0    Male  161.590030  90.877589          B  34.803881
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["Smoking"]=le.fit_transform(data["Smoking"])
data
# Out:
#         Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0              1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1              2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2              3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3              NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4              5.0  23.0  Female         NaN  46.234173          O        NaN
# ...            ...   ...     ...         ...        ...        ...        ...
# 199995         NaN  24.0    Male  176.503260  95.756997          B  30.737254
# 199996     99997.0  29.0  Female  163.917675  45.225194        NaN  16.831734
# 199997     99998.0  34.0  Female         NaN  99.648914        NaN  33.189303
# 199998     99999.0  30.0  Female  156.446944  50.142824          A  20.486823
# 199999    100000.0  20.0  Female  153.927410  99.928405          O  42.175189
#
# ...

# %%
plt.hist(data["Smoking"])
plt.show()

# %%
 x = df.drop(['Heigh','Weight'],axis=1])
 x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size =0.33,random_state = 0)
#
# NameError: name 'x' is not defined
